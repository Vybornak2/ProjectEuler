# %%
import sys

sys.path.append("../..")
from tools.task_description import display_description

display_description()

# %% [markdown]
# keywords:
# - project euler

# %% [markdown]
# ## Brute-force Solution

# %%
def main_bf():
    pass

# %%
# %%timeit
main_bf()

# %%
main_bf()

# %% [markdown]
# ## Optimized Solution
# - notes

# %%
def main_opt():
    pass

# %%
# %%timeit
main_opt()

# %%
main_opt()
