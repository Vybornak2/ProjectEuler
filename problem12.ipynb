# %%
"""

The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:

1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...

Let us list the factors of the first seven triangle numbers:

 1: 1
 3: 1,3
 6: 1,2,3,6
10: 1,2,5,10
15: 1,3,5,15
21: 1,3,7,21
28: 1,2,4,7,14,28
We can see that 28 is the first triangle number to have over five divisors.

What is the value of the first triangle number to have over five hundred divisors?

"""

import numpy as np

# prime factorization . but we dont need that in such form - only amount of primes

"""
def Prime_search(N):
    print('\n N=',N)
    no_prime = np.ones(int(N ** 0.5 + 2))
    #print(no_prime)
    prime_sq = {}
    p = 2
    k = 0
    while N > p ** 2:
        #print('p=',p)
        if N % p == 0 and no_prime[p] == 1:
            prime_sq[k] = p
            k += 1
            N = N / p
            #print('N=',N)
        else:
            qi = 2
            q = p * qi
            while N > q ** 2:
                #print('q=',q)
                no_prime[q] = 0
                qi += 1
                q *= p * qi
                #print(no_prime)
            p += 1
    if N != 1:
        prime_sq[k] = N
    return prime_sq
"""

def div_amount(N):
    #print('\nN=',N)
    no_prime = np.ones(int(N ** 0.5 + 2))
    p = 2
    first_div = True
    fact_amount = 0
    while N > p ** 2:
        #print('p=',p)
        #print('N=',N)
        if N % p == 0 and no_prime[p] == 1:
            
            if first_div == True:
                fact_amount_old = fact_amount
                fact_amount = fact_amount * 2 + 1
                first_div = False
                #print('First prime ',p,', amount of factors is ',fact_amount)
            else:
                fact_amount = fact_amount + fact_amount_old + 1
                #print('amount of previous factors is', fact_amount_old)
                #print('not a first prime ',p,', amount of factors is ',fact_amount)
            
            N = N / p
        else:         
            qi = 2
            q = p * qi
            while N > q ** 2:
                #print('q=',q)
                no_prime[q] = 0
                qi += 1
                q *= p * qi
                #print(no_prime)
            p += 1
            first_div = True
    #print('cycle over, N=', N)
    if N != 1 and N > p:
        fact_amount = fact_amount * 2 + 1
    
    fact_amount += 1
    return fact_amount



tria_num = 0
i = 0

while X < 500 :
    i += 1
    tria_num += i
    X = div_amount(tria_num)
print('X=',X)
print('num=',tria_num)
# Out:
# X= 576
# num= 76576500
