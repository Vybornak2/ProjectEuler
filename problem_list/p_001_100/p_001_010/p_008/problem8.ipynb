# %%
"""
The four adjacent digits in the 1000-digit number that have the greatest product are 9 × 9 × 8 × 9 = 5832.
Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?


"""

num = '...'

# first we find zeros / not necessary actually .. did it in same loop

zeros1={}
zeros2={}

# we are have problem with any zero withing range of 13 digists so after 0 we do not have to search for other one for 13 digets

i = 0
k = 0
while i < len(num):
    if int(num[i]) == 0:
        zeros1[k] = i
        k += 1
        i += 13
    i += 1
    
# actualy fidning all zeros just to see if it is correct
    
k = 0
for i in range(0,len(num)):
    if int(num[i]) == 0:
        zeros2[k] = i
        k += 1

print(zeros1)
print(zeros2)
        
mul = 1
len_mul = 13

for i in range(0,len_mul):
    mul *= int(num[i])
    
mul_M=mul

for i in range(0,len(num) - len_mul):
    a = int(num[i + len_mul])
    if a == 0:
        a = 1
        viable = False
        viable_n = 13 + 1
        
    if not viable and viable_n > 0:
        viable_n -= 1
    else:
        viable = True
         
    b = int(num[i])
    if b == 0:
        b = 1
        
    mul = mul * a / b
    #print(mul)
    print(i)
    print(viable)
    if mul > mul_M and viable:
        mul_M = mul

print(mul_M)
# Out:
# {0: 13, 1: 57, 2: 79, 3: 107, 4: 124, 5: 142, 6: 170, 7: 194, 8: 210, 9: 230, 10: 263, 11: 283, 12: 301, 13: 319, 14: 334, 15: 351, 16: 371, 17: 390, 18: 408, 19: 422, 20: 440, 21: 456, 22: 471, 23: 517, 24: 564, 25: 595, 26: 612, 27: 631, 28: 672, 29: 742, 30: 761, 31: 778, 32: 796, 33: 810, 34: 828, 35: 845, 36: 861, 37: 877, 38: 893, 39: 912, 40: 936, 41: 966, 42: 987}
# ...
