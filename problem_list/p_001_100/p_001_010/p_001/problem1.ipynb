# %%
# sum of all numbres that are multiples of 3 or 5 bellow 1000
sum=0
i=1;
while i < 1000:
    if i % 3 == 0:
        sum += i
        #print(i)
    if i % 5 == 0:
        sum += i
        #print(i)
    if i % 3 == 0 and i % 5 == 0:
        sum -= i
    print('step: ', i, ' sum is: ', sum)
    i += 1
print(sum)
# Out:
# step:  1  sum is:  0
# step:  2  sum is:  0
# step:  3  sum is:  3
# step:  4  sum is:  3
# step:  5  sum is:  8
# step:  6  sum is:  14
# step:  7  sum is:  14
# step:  8  sum is:  14
# step:  9  sum is:  23
# step:  10  sum is:  33
# step:  11  sum is:  33
# step:  12  sum is:  45
# step:  13  sum is:  45
# step:  14  sum is:  45
# step:  15  sum is:  60
# step:  16  sum is:  60
# step:  17  sum is:  60
# step:  18  sum is:  78
# step:  19  sum is:  78
# step:  20  sum is:  98
# step:  21  sum is:  119
# step:  22  sum is:  119
# step:  23  sum is:  119
# step:  24  sum is:  143
# step:  25  sum is:  168
# step:  26  sum is:  168
# step:  27  sum is:  195
# step:  28  sum is:  195
# step:  29  sum is:  195
# step:  30  sum is:  225
# step:  31  sum is:  225
# step:  32  sum is:  225
# step:  33  sum is:  258
# step:  34  sum is:  258
# step:  35  sum is:  293
# step:  36  sum is:  329
# step:  37  sum is:  329
# step:  38  sum is:  329
# step:  39  sum is:  368
# ...
