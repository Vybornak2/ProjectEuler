# %%
import sys

sys.path.append("../..")
from tools.task_description import display_description

display_description()
# Out:
# # Sub-string Divisibility
#
# [Problem Link](https://projecteuler.net/problem=43)
#
# The number, $1406357289$, is a $0$ to $9$ pandigital number because it is made up of each of the digits $0$ to $9$ in some order, but it also has a rather interesting sub-string divisibility property.
#
# Let $d_1$ be the $1$st digit, $d_2$ be the $2$nd digit, and so on. In this way, we note the following:
#
# * $d_2d_3d_4=406$ is divisible by $2$
# * $d_3d_4d_5=063$ is divisible by $3$
# * $d_4d_5d_6=635$ is divisible by $5$
# * $d_5d_6d_7=357$ is divisible by $7$
# * $d_6d_7d_8=572$ is divisible by $11$
# * $d_7d_8d_9=728$ is divisible by $13$
# * $d_8d_9d_{10}=289$ is divisible by $17$
#
# Find the sum of all $0$ to $9$ pandigital numbers with this property.

# %% [markdown]
# ## Brute-force Solution

# %%
from itertools import permutations


def main_bf():
    total_sum = 0
    for perm in permutations(range(10), 10):
        d1, d2, d3, d4, d5, d6, d7, d8, d9, d10 = perm
        if d4 % 2 != 0:
            continue
        if (d3 + d4 + d5) % 3 != 0:
            continue
        if d6 not in (0, 5):
            continue
        if (100 * d5 + 10 * d6 + d7) % 7 != 0:
            continue
        if (100 * d6 + 10 * d7 + d8) % 11 != 0:
            continue
        if (100 * d7 + 10 * d8 + d9) % 13 != 0:
            continue
        if (100 * d8 + 10 * d9 + d10) % 17 != 0:
            continue
        number = (
            d1 * 10**9
            + d2 * 10**8
            + d3 * 10**7
            + d4 * 10**6
            + d5 * 10**5
            + d6 * 10**4
            + d7 * 10**3
            + d8 * 10**2
            + d9 * 10**1
            + d10
        )
        total_sum += number
    return total_sum

# %%
# %%timeit
main_bf()
# Out:
# 372 ms ± 4.09 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
main_bf()
# Out:
# 16695334890

# %% [markdown]
# ## Optimized Solution
#
# Notes:
# 1. instead of checking all permutations, we generate the numbers in a specific order
# 2. instead of nested loops and if conditions, we use recursion

# %%
DIVISORS = [2, 3, 5, 7, 11, 13, 17]


def search(current_suffix: str, divisor_idx: int) -> int:
    """Search for valid numbers with the given suffix and divisor index.

    Valid numbers must have unique digits and satisfy the divisibility property.
    Valid numbers are added to the total sum.

    Args:
        current_suffix (str): The current suffix of the number being constructed.
        divisor_idx (int): The index of the divisor to check against.

    Returns:
        int: The sum of valid numbers found.
    """
    if divisor_idx < 0:  # first digit
        missing = set("0123456789") - set(current_suffix)
        d1 = missing.pop()
        return int(d1 + current_suffix)  # complete number

    total = 0
    target_divisor = DIVISORS[divisor_idx]

    suffix_head = current_suffix[:2]

    for d in "0123456789":
        if (d not in current_suffix) and (int(d + suffix_head) % target_divisor == 0):
            total += search(d + current_suffix, divisor_idx - 1)
    return total


def main_opt():
    total_sum = 0
    for i in range(17, 1000, 17):
        s = f"{i:03d}"
        if len(set(s)) == 3:
            total_sum += search(s, 5)

    return total_sum

# %%
# %%timeit
main_opt()
# Out:
# 142 μs ± 1.76 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
main_opt()
# Out:
# 16695334890
